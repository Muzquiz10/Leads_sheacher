# %%
import os
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import time
import os
from dotenv import load_dotenv

# %%
## Función

def apendizador_leads(ruta,sector):
    dfs = []

    for entry in os.scandir(ruta):
        if entry.is_file() and sector in entry.name:
            df = pd.read_csv(entry.path)

            # -------------------------
            # LIMPIEZA DE DATOS (ejemplo)
            # -------------------------
            df = df.dropna(subset=['Email'])          # elimina registros sin email
        

            # Guarda el dataframe limpio
            dfs.append(df)

    # Unir todos los dataframes en uno solo
    df_final = pd.concat(dfs, ignore_index=True)
    df_final.to_excel(ruta + f"/leads_{sector}_completo.xlsx", index=False)

    return df_final

# %%
df = apendizador_leads(r"C:\Users\ejgar\OneDrive\Documentos\GitHub\Leads_sheacher\data\7.Spa","Spa")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     111 non-null    object
#  1   Direccion  111 non-null    object
#  2   Telefono   110 non-null    object
#  3   Web        111 non-null    object
#  4   Email      111 non-null    object
#  5   Sector     111 non-null    object
#  6   Ubicacion  111 non-null    object
# dtypes: object(7)
# memory usage: 6.2+ KB

# %%
df.head()
# Out:
#                                               Nombre  \
# 0  JG fitness Alcobendas | Entrenador personal & ...
# 1  Nkon Training | Centro de Entrenamiento Person...
# 2  SANO Alcobendas - Entrenamiento Personal y Gru...
# 3  ENTRENADOR PERSONAL (PAUL CORDONES) Moraleja -...
# 4                    Jorge Morillas Personal Trainer
#
#                                            Direccion          Telefono  \
# 0   P.º de la Chopera, 182, 28100 Alcobendas, Madrid  +34 604 97 78 56
# 1  Av. de la Industria, 34, Primera Planta. Local...               NaN
# 2  Av. de Camilo José Cela, 34, 28108 Alcobendas,...  +34 614 14 27 03
# 3       Pl. de la Moraleja, 28109 Alcobendas, Madrid  +34 653 04 36 43
# 4    C. de la Libertad, 49, 28100 Alcobendas, Madrid  +34 689 48 86 33
#
#                                                  Web  \
# 0           https://jgfitness.es/centros/alcobendas/
# 1                       https://www.nkontraining.es/
# 2  https://www.sanocenter.es/empresas/sano-alcobe...
# 3                           http://paulcordones.com/
# 4                         https://jorgemorillas.com/
#
#                                 Email               Sector   Ubicacion
# 0        DSC03954_@sharonlopez-1.webp  Entrenador Personal  Alcobendas
# 1                info@nkontraining.es  Entrenador Personal  Alcobendas
# 2  sanomadridalcobendas@sanocenter.es  Entrenador Personal  Alcobendas
# 3               info@paulcordones.com  Entrenador Personal  Alcobendas
# 4     jorgemorillas.trainer@gmail.com  Entrenador Personal  Alcobendas

# %% [markdown]
# ## Envío de mail

# %%
df = pd.read_excel(r"equipo_de_futbol.xlsx")

# %%
df =df.dropna(subset=['email'])

# %%
df = df[['name','email']]

# %%
df
# Out:
#                                              name  \
# 0                       Club de Futbol Madrid Río
# 1                       Club de Futbol Madrid Río
# 2                       Club de Futbol Madrid Río
# 3    Ligas de Futbol 7 en Madrid - Madrid fútbol7
# 4                           UNION DEPORTIVA USERA
# ..                                            ...
# 726          Polideportivo Municipal Dehesa Boyal
# 727          Polideportivo Municipal Dehesa Boyal
# 728          Polideportivo Municipal Dehesa Boyal
# 730                             E.F.M.O. Boadilla
# 731         Estadio Municipal Facundo Rivas Pérez
#
#                                  email
# 0     montecarmelo@futbolmadridrio.com
# 1          escuela@futbolmadridrio.com
# 2                 info@cfmadridrio.com
# 3                info@madridfutbol7.es
# 4        uniondeportivausera@gmail.com
# ..                                 ...
# 726    comunicacion@gruponordestada.es
# 727               info.dehesa@aossa.es
# 728             ludotecasanse@aossa.es
# 730  efmadridoesteboadilla@hotmail.com
# 731         comunicacion@cdelalamo.com
#
# [607 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 607 entries, 0 to 731
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    607 non-null    object
#  1   email   607 non-null    object
# dtypes: object(2)
# memory usage: 14.2+ KB

# %%
len(df)
# Out:
# 607

# %% [markdown]
# ## Revisión duplicados

# %%
df.duplicated().any()
# Out:
# np.True_

# %%
## Mejorar lóica para no enviar mail a contactos duplicados y a mails no activos
df = df[df[df.duplicated(keep=False)]!=df['']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ejgar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df = df[df[df.duplicated(keep=False)]!=df['']]
#
# File c:\Users\ejgar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\ejgar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ''

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 11 to 466
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    165 non-null    object
#  1   email   165 non-null    object
# dtypes: object(2)
# memory usage: 3.9+ KB

# %%
len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 len(df)
#
# NameError: name 'df' is not defined

# %%
# Particionado del Dataframe
df = df.iloc[0:100] ## Para particionar el df en varias partes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 135
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    100 non-null    object
#  1   email   100 non-null    object
# dtypes: object(2)
# memory usage: 2.3+ KB

# %%
len(df)
# Out:
# 100

# %%
# Credenciales Gmail
load_dotenv()

EMAIL_REMITENTE = os.getenv("EMAIL_REMITENTE")
PASSWORD_APP = os.getenv("PASSWORD_APP")
SMTP_SERVER = os.getenv("SMTP_SERVER")
SMTP_PORT = int(os.getenv("SMTP_PORT"))

EMAIL_REMITENTE = EMAIL_REMITENTE
PASSWORD_APP = PASSWORD_APP

# servidor SMTP de Gmail
SMTP_SERVER = SMTP_SERVER
SMTP_PORT = SMTP_PORT

# conexión
server = smtplib.SMTP(SMTP_SERVER, SMTP_PORT)
server.starttls()
server.login(EMAIL_REMITENTE, PASSWORD_APP)

#Contador de mails enviaados
contador = 0

for _, row in df.iterrows():
    ### Pruebas ###
    # nombre = "Enrique" #Para pruebas
    # destinatario = "muzquiz.10@gmail.com"  #Para pruebas
    ## Fin Pruebas ##

    destinatario = row['email']
    nombre = row['name']
    
    mensaje = MIMEMultipart()
    mensaje['From'] = EMAIL_REMITENTE
    mensaje['To'] = destinatario
    mensaje['Subject'] = "¿Necesitas ayuda con tus datos o tu presencia online? Entonces esto te interesa mi correo"

    cuerpo = f"""
Hola {nombre},

Soy Enrique García, consultor freelance y fundador de EGM Analytics.

Ayudo a pequeños negocios y profesionales en dos áreas clave:

Business Intelligence y análisis de datos: organización y modelado de datos, automatización de informes, análisis para la toma de decisiones y mejora de procesos basados en datos: https://egmanalytics.com/BI_service.html

Desarrollo web profesional: creación de páginas web claras y bien estructuradas que ayuden a tener presencia online, transmitir credibilidad y mostrar el negocio de forma profesional: https://egmanalytics.com/dev_web.html

En muchos casos me encuentro con empresas que tienen datos dispersos o infrautilizados y, al mismo tiempo, una presencia digital que no refleja realmente lo que hacen o el valor que aportan.

Mi enfoque es práctico y cercano: soluciones sencillas, bien pensadas y adaptadas a cada negocio, sin complicaciones innecesarias.

Si te parece, podemos agendar una llamada breve (15–20 minutos, sin compromiso) para comentar tu situación y ver si puedo ayudarte en alguno de estos ámbitos.

También me puedes conocer a través de mi web: https://egmanalytics.com

Un saludo,


Enrique García
Consultor en Data, BI y Desarrollo Web
EGM Analytics
https://egmanalytics.com
"""
    mensaje.attach(MIMEText(cuerpo, 'plain'))

    try:
        server.send_message(mensaje)
        print(f"✔ Email enviado a {destinatario}")
        contador += 1
        print(f"Emails enviados hasta ahora: {contador}")
        time.sleep(15)
    except Exception as e:
        print(f"❌ Error enviando a {destinatario}: {e}")
        time.sleep(15)

server.quit()
# Out:
# ✔ Email enviado a montecarmelo@futbolmadridrio.com
# Emails enviados hasta ahora: 1
# ✔ Email enviado a escuela@futbolmadridrio.com
# Emails enviados hasta ahora: 2
# ✔ Email enviado a info@cfmadridrio.com
# Emails enviados hasta ahora: 3
# ✔ Email enviado a info@madridfutbol7.es
# Emails enviados hasta ahora: 4
# ✔ Email enviado a uniondeportivausera@gmail.com
# Emails enviados hasta ahora: 5
# ✔ Email enviado a ndeportivausera@gmail.com
# Emails enviados hasta ahora: 6
# ✔ Email enviado a competicion@redsports.es
# Emails enviados hasta ahora: 7
# ✔ Email enviado a ligas@redfutbolsiete.com
# Emails enviados hasta ahora: 8
# ✔ Email enviado a presidente@s485697842.mialojamiento.es
# Emails enviados hasta ahora: 9
# ✔ Email enviado a marketing.sportinghortaleza@gmail.com
# Emails enviados hasta ahora: 10
# ✔ Email enviado a miguelromon4@gmail.com
# Emails enviados hasta ahora: 11
# ✔ Email enviado a info@cdcanillas.com
# Emails enviados hasta ahora: 12
# ✔ Email enviado a tecnificacion@cdcanillas.com
# Emails enviados hasta ahora: 13
# ✔ Email enviado a marketing@cdcanillas.com
# Emails enviados hasta ahora: 14
# ✔ Email enviado a sadvillaverdesanandres@gmail.com
# Emails enviados hasta ahora: 15
# ✔ Email enviado a competiciones@ligasfutbolsiete.com
# Emails enviados hasta ahora: 16
# ✔ Email enviado a info@ligasfutbolsiete.com
# Emails enviados hasta ahora: 17
# ✔ Email enviado a juan@sportzentral.com
# Emails enviados hasta ahora: 18
# ✔ Email enviado a info@futbolclubbritanico.com
# Emails enviados hasta ahora: 19
# ✔ Email enviado a support@pitchero.com
# Emails enviados hasta ahora: 20
# ✔ Email enviado a aulacf@hotmail.com
# Emails enviados hasta ahora: 21
# ✔ Email enviado a info@club-brezo-osuna.com
# Emails enviados hasta ahora: 22
# ✔ Email enviado a info@aulacf.es
# Emails enviados hasta ahora: 23
# ✔ Email enviado a comunicacion@cdvillamanta.es
# Emails enviados hasta ahora: 24
# ✔ Email enviado a cdchamberi@gmail.com
# Emails enviados hasta ahora: 25
# ✔ Email enviado a cdgoya1954@gmail.com
# Emails enviados hasta ahora: 26
# ✔ Email enviado a jugargoya@gmail.com
# Emails enviados hasta ahora: 27
# ✔ Email enviado a marketingcdgoya@gmail.com
# Emails enviados hasta ahora: 28
# ✔ Email enviado a administracion@efcarabanchel.com
# Emails enviados hasta ahora: 29
# ✔ Email enviado a info@efcarabanchel.com
# Emails enviados hasta ahora: 30
# ✔ Email enviado a comunicacion@efcarabanchel.com
# Emails enviados hasta ahora: 31
# ✔ Email enviado a escuela@aluchefutbolsala.es
# Emails enviados hasta ahora: 32
# ✔ Email enviado a info@if7sports.com
# Emails enviados hasta ahora: 33
# ✔ Email enviado a hola@triboost.club
# Emails enviados hasta ahora: 34
# ✔ Email enviado a informacion@ocioydeportecanal.es
# Emails enviados hasta ahora: 35
# ✔ Email enviado a ligafutbol@ocioydeportecanal.es
# Emails enviados hasta ahora: 36
# ✔ Email enviado a buzon_transparencia@ocioydeportecanal.es
# Emails enviados hasta ahora: 37
# ✔ Email enviado a info@cdorcasursinfronteras.com
# Emails enviados hasta ahora: 38
# ✔ Email enviado a informacionavlachimenea@gmail.com
# Emails enviados hasta ahora: 39
# ✔ Email enviado a informacionavlachimena@gmail.com
# Emails enviados hasta ahora: 40
# ✔ Email enviado a surlatina09@gmail.com
# Emails enviados hasta ahora: 41
# ✔ Email enviado a info@cdmadridsurlatina.com
# Emails enviados hasta ahora: 42
# ✔ Email enviado a direcciondeportiva@cdmadridsurlatina.com
# Emails enviados hasta ahora: 43
# ✔ Email enviado a madrid.barbariansrfc@gmail.com
# Emails enviados hasta ahora: 44
# ✔ Email enviado a Cfitzg6505@aol.Com
# Emails enviados hasta ahora: 45
# ✔ Email enviado a Gjc3839@aol.Com
# Emails enviados hasta ahora: 46
# ✔ Email enviado a Studwld@aol.Com
# Emails enviados hasta ahora: 47
# ✔ Email enviado a gerencia@caumadridrugby.com
# Emails enviados hasta ahora: 48
# ✔ Email enviado a rfebm@rfebm.com
# Emails enviados hasta ahora: 49
# ✔ Email enviado a marian@madrid.es
# Emails enviados hasta ahora: 50
# ✔ Email enviado a sandraa@madrid.es
# Emails enviados hasta ahora: 51
# ✔ Email enviado a herreroa@madrid.es
# Emails enviados hasta ahora: 52
# ✔ Email enviado a info@cdmako.com
# Emails enviados hasta ahora: 53
# ✔ Email enviado a makocarabanchel@gmail.com
# Emails enviados hasta ahora: 54
# ✔ Email enviado a administracion@eleva.space
# Emails enviados hasta ahora: 55
# ✔ Email enviado a lauradavis@aaawin.com
# Emails enviados hasta ahora: 56
# ✔ Email enviado a davidfly@aaawin.com
# Emails enviados hasta ahora: 57
# ✔ Email enviado a kayriley@aaawin.com
# Emails enviados hasta ahora: 58
# ✔ Email enviado a gigantesad@gmail.com
# Emails enviados hasta ahora: 59
# ✔ Email enviado a lauradavis@aaawin.com
# Emails enviados hasta ahora: 60
# ✔ Email enviado a davidfly@aaawin.com
# Emails enviados hasta ahora: 61
# ✔ Email enviado a kayriley@aaawin.com
# Emails enviados hasta ahora: 62
# ✔ Email enviado a secretariadireccion@canterafc.es
# Emails enviados hasta ahora: 63
# ✔ Email enviado a josemariacerezo@canterafc.es
# Emails enviados hasta ahora: 64
# ✔ Email enviado a comitededisciplina@canterafc.es
# Emails enviados hasta ahora: 65
# ✔ Email enviado a antoniobrunetelopez@gmail.com
# Emails enviados hasta ahora: 66
# ✔ Email enviado a administracion@continox.es
# Emails enviados hasta ahora: 67
# ✔ Email enviado a contacto@therunclub.es
# Emails enviados hasta ahora: 68
# ✔ Email enviado a info@madridbeachvolleyacademy.com
# Emails enviados hasta ahora: 69
# ✔ Email enviado a abonados@ccvm.es
# Emails enviados hasta ahora: 70
# ✔ Email enviado a deportes@ccvm.es
# Emails enviados hasta ahora: 71
# ✔ Email enviado a contabilidad@ccvm.es
# Emails enviados hasta ahora: 72
# ✔ Email enviado a cuentacuentos@paracuellosdejarama.es
# Emails enviados hasta ahora: 73
# ✔ Email enviado a laterminal@paracuellosdejarama.es
# Emails enviados hasta ahora: 74
# ✔ Email enviado a declaracionesresponsables@paracuellosdejarama.es
# Emails enviados hasta ahora: 75
# ✔ Email enviado a jonwoodward1975@gmail.com
# Emails enviados hasta ahora: 76
# ✔ Email enviado a lclark@genasys.com
# Emails enviados hasta ahora: 77
# ✔ Email enviado a comercial@atleticodemadrid.com
# Emails enviados hasta ahora: 78
# ✔ Email enviado a rabril@clubatleticodemadrid.com
# Emails enviados hasta ahora: 79
# ✔ Email enviado a lalcaraz@atleticodemadrid.com
# Emails enviados hasta ahora: 80
# ✔ Email enviado a info@clubbombon.com
# Emails enviados hasta ahora: 81
# ✔ Email enviado a asociacion@clevi.com
# Emails enviados hasta ahora: 82
# ✔ Email enviado a asociacionclevi@clevi.org
# Emails enviados hasta ahora: 83
# ✔ Email enviado a asociacion@clevi.org
# Emails enviados hasta ahora: 84
# ✔ Email enviado a marian@madrid.es
# Emails enviados hasta ahora: 85
# ✔ Email enviado a sandraa@madrid.es
# Emails enviados hasta ahora: 86
# ✔ Email enviado a herreroa@madrid.es
# Emails enviados hasta ahora: 87
# ✔ Email enviado a studio54madrid@hotmail.com
# Emails enviados hasta ahora: 88
# ✔ Email enviado a 54@studio54madrid.com
# Emails enviados hasta ahora: 89
# ✔ Email enviado a paracuellosrugbyunion@gmail.com
# Emails enviados hasta ahora: 90
# ✔ Email enviado a deportivas.madrid@asisa.es
# Emails enviados hasta ahora: 91
# ✔ Email enviado a info@paracuellosrugby.com
# Emails enviados hasta ahora: 92
# ✔ Email enviado a salvador@shokomadrid.com
# Emails enviados hasta ahora: 93
# ✔ Email enviado a isabel@shokomadrid.com
# Emails enviados hasta ahora: 94
# ✔ Email enviado a diego@shokomadrid.com
# Emails enviados hasta ahora: 95
# ✔ Email enviado a comunicacion@deliriochueca.com
# Emails enviados hasta ahora: 96
# ✔ Email enviado a listas@deliriochueca.com
# Emails enviados hasta ahora: 97
# ✔ Email enviado a lotusbjjmadrid@hotmail.com
# Emails enviados hasta ahora: 98
# ✔ Email enviado a marbella.lynett@gmail.com
# Emails enviados hasta ahora: 99
# ✔ Email enviado a abonados@ccvm.es
# Emails enviados hasta ahora: 100
# (221,
#  b'2.0.0 closing connection ffacd0b85a97d-43fe4e3a79esm64022441f8f.17 - gsmtp')
