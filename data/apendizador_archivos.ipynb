# %%
import os
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import time
import os
from dotenv import load_dotenv

# %%
## Función

def apendizador_leads(ruta,sector):
    dfs = []

    for entry in os.scandir(ruta):
        if entry.is_file() and sector in entry.name:
            df = pd.read_csv(entry.path)

            # -------------------------
            # LIMPIEZA DE DATOS (ejemplo)
            # -------------------------
            df = df.dropna(subset=['Email'])          # elimina registros sin email
        

            # Guarda el dataframe limpio
            dfs.append(df)

    # Unir todos los dataframes en uno solo
    df_final = pd.concat(dfs, ignore_index=True)
    df_final.to_excel(ruta + f"/leads_{sector}_completo.xlsx", index=False)

    return df_final

# %%
df = apendizador_leads(r"C:\Users\ejgar\OneDrive\Documentos\GitHub\Leads_sheacher\data\7.Spa","Spa")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     111 non-null    object
#  1   Direccion  111 non-null    object
#  2   Telefono   110 non-null    object
#  3   Web        111 non-null    object
#  4   Email      111 non-null    object
#  5   Sector     111 non-null    object
#  6   Ubicacion  111 non-null    object
# dtypes: object(7)
# memory usage: 6.2+ KB

# %%
df.head()
# Out:
#                                               Nombre  \
# 0  JG fitness Alcobendas | Entrenador personal & ...
# 1  Nkon Training | Centro de Entrenamiento Person...
# 2  SANO Alcobendas - Entrenamiento Personal y Gru...
# 3  ENTRENADOR PERSONAL (PAUL CORDONES) Moraleja -...
# 4                    Jorge Morillas Personal Trainer
#
#                                            Direccion          Telefono  \
# 0   P.º de la Chopera, 182, 28100 Alcobendas, Madrid  +34 604 97 78 56
# 1  Av. de la Industria, 34, Primera Planta. Local...               NaN
# 2  Av. de Camilo José Cela, 34, 28108 Alcobendas,...  +34 614 14 27 03
# 3       Pl. de la Moraleja, 28109 Alcobendas, Madrid  +34 653 04 36 43
# 4    C. de la Libertad, 49, 28100 Alcobendas, Madrid  +34 689 48 86 33
#
#                                                  Web  \
# 0           https://jgfitness.es/centros/alcobendas/
# 1                       https://www.nkontraining.es/
# 2  https://www.sanocenter.es/empresas/sano-alcobe...
# 3                           http://paulcordones.com/
# 4                         https://jorgemorillas.com/
#
#                                 Email               Sector   Ubicacion
# 0        DSC03954_@sharonlopez-1.webp  Entrenador Personal  Alcobendas
# 1                info@nkontraining.es  Entrenador Personal  Alcobendas
# 2  sanomadridalcobendas@sanocenter.es  Entrenador Personal  Alcobendas
# 3               info@paulcordones.com  Entrenador Personal  Alcobendas
# 4     jorgemorillas.trainer@gmail.com  Entrenador Personal  Alcobendas

# %% [markdown]
# ## Envío de mail

# %%
df = pd.read_excel(r"C:\Users\ejgar\OneDrive\Documentos\GitHub\Leads_sheacher\data\9.Hoteles\hotel_3_estrellas_valencia_+1.xlsx")

# %%
df =df.dropna(subset=['email'])

# %%
df = df[['name','email']]

# %%
df
# Out:
#                                                 name  \
# 0                               Hotel Rural El Navío
# 1                               Hotel Rural El Navío
# 2                          Hotel Royal Garden Villas
# 3                          Hotel Royal Garden Villas
# 4                          Hotel Royal Garden Villas
# ..                                               ...
# 156                                   Finca La Tosca
# 160              Elite Luxury Vacations & Properties
# 162  Villa Caterina, Luxury Villa in Adeje, Tenerife
# 163                                        La Casita
# 164                                Villa Dhanvantari
#
#                                email
# 0                    info@elnavio.es
# 1                reservas@elnavio.es
# 2      marketing@grupogolfresort.com
# 3     reservas@royalgardenvillas.com
# 4    recepcion@royalgardenvillas.com
# ..                               ...
# 156           post@teneriffa-haus.de
# 160    info@eliteluxuryvacations.com
# 162  sainversionescanarias@gmail.com
# 163             cafe@lacasitacafe.es
# 164        info@villadhanvantari.com
#
# [124 rows x 2 columns]

# %% [markdown]
# ## Revisión duplicados

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [name, email]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124 entries, 0 to 164
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    124 non-null    object
#  1   email   124 non-null    object
# dtypes: object(2)
# memory usage: 2.9+ KB

# %%
# Particionado del Dataframe
df = df.iloc[51:] ## Para particionar el df en varias partes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73 entries, 55 to 164
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    73 non-null     object
#  1   email   73 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
df_particionado.head()
# Out:
#                              name                            email
# 0  Dental Clinic Puerta de Toledo   info@clinicapuertadetoledo.com
# 1  Dental Clinic Puerta de Toledo  clinicapuertadetoledo@gmail.com
# 2        Clinica Dental StyleDent               info@styledent.com
# 3                Clínica Q-Dental              clinica@q-dental.es
# 4                Clínica Q-Dental                 info@q-dental.es

# %%
# Credenciales Gmail
load_dotenv()

EMAIL_REMITENTE = os.getenv("EMAIL_REMITENTE")
PASSWORD_APP = os.getenv("PASSWORD_APP")
SMTP_SERVER = os.getenv("SMTP_SERVER")
SMTP_PORT = int(os.getenv("SMTP_PORT"))

EMAIL_REMITENTE = EMAIL_REMITENTE
PASSWORD_APP = PASSWORD_APP

# servidor SMTP de Gmail
SMTP_SERVER = SMTP_SERVER
SMTP_PORT = SMTP_PORT

# conexión
server = smtplib.SMTP(SMTP_SERVER, SMTP_PORT)
server.starttls()
server.login(EMAIL_REMITENTE, PASSWORD_APP)

#Contador de mails enviaados
contador = 0

for _, row in df.iterrows():
    ### Pruebas ###
    # nombre = "Enrique" #Para pruebas
    # destinatario = "muzquiz.10@gmail.com"  #Para pruebas
    ## Fin Pruebas ##

    destinatario = row['email']
    nombre = row['name']
    
    mensaje = MIMEMultipart()
    mensaje['From'] = EMAIL_REMITENTE
    mensaje['To'] = destinatario
    mensaje['Subject'] = "Datos claros y una presencia online profesional para tu negocio"

    cuerpo = f"""
Hola {nombre},

Soy Enrique García, consultor freelance y fundador de EGM Analytics.

Ayudo a pequeños negocios y profesionales en dos áreas clave:

Business Intelligence y análisis de datos: organización y modelado de datos, automatización de informes, análisis para la toma de decisiones y mejora de procesos basados en datos: https://egmanalytics.com/BI_service.html

Desarrollo web profesional: creación de páginas web claras y bien estructuradas que ayuden a tener presencia online, transmitir credibilidad y mostrar el negocio de forma profesional: https://egmanalytics.com/dev_web.html

En muchos casos me encuentro con empresas que tienen datos dispersos o infrautilizados y, al mismo tiempo, una presencia digital que no refleja realmente lo que hacen o el valor que aportan.

Mi enfoque es práctico y cercano: soluciones sencillas, bien pensadas y adaptadas a cada negocio, sin complicaciones innecesarias.

Si te parece, podemos agendar una llamada breve (15–20 minutos, sin compromiso) para comentar tu situación y ver si puedo ayudarte en alguno de estos ámbitos.

También me puedes conocer a través de mi web: https://egmanalytics.com

Un saludo,


Enrique García
Consultor en Data, BI y Desarrollo Web
EGM Analytics
https://egmanalytics.com
"""
    mensaje.attach(MIMEText(cuerpo, 'plain'))

    try:
        server.send_message(mensaje)
        print(f"✔ Email enviado a {destinatario}")
        contador += 1
        print(f"Emails enviados hasta ahora: {contador}")
        time.sleep(15)
    except Exception as e:
        print(f"❌ Error enviando a {destinatario}: {e}")
        time.sleep(15)

server.quit()
# Out:
# ✔ Email enviado a lmacias@intercorpgrp.com
# Emails enviados hasta ahora: 1
# ✔ Email enviado a ecosta@intercorpgrp.com
# Emails enviados hasta ahora: 2
# ✔ Email enviado a jasin@intercorpgrp.com
# Emails enviados hasta ahora: 3
# ✔ Email enviado a relation.client@groupepvcp.com
# Emails enviados hasta ahora: 4
# ✔ Email enviado a seminaires@groupepvcp.com
# Emails enviados hasta ahora: 5
# ✔ Email enviado a commercial.groupes@groupepvcp.com
# Emails enviados hasta ahora: 6
# ✔ Email enviado a antonio@primehomestenerife.com
# Emails enviados hasta ahora: 7
# ✔ Email enviado a angelica@primehomestenerife.com
# Emails enviados hasta ahora: 8
# ✔ Email enviado a info@primehomestenerife.com
# Emails enviados hasta ahora: 9
# ✔ Email enviado a reservas@vigiliapark.com
# Emails enviados hasta ahora: 10
# ✔ Email enviado a comunidadpropietarios@vigiliapark.com
# Emails enviados hasta ahora: 11
# ✔ Email enviado a direccionvigilia@vigiliapark.com
# Emails enviados hasta ahora: 12
# ✔ Email enviado a fondacentral@gmail.com
# Emails enviados hasta ahora: 13
# ✔ Email enviado a hperez@bahiaprincipe.com
# Emails enviados hasta ahora: 14
# ✔ Email enviado a hmontijano@bahiaprincipe.com
# Emails enviados hasta ahora: 15
# ✔ Email enviado a natdel29@yahoo.com
# Emails enviados hasta ahora: 16
# ✔ Email enviado a info@miposadita.es
# Emails enviados hasta ahora: 17
# ✔ Email enviado a bonsai@stilhotels.com
# Emails enviados hasta ahora: 18
# ✔ Email enviado a reservascartagena@stilhotels.com
# Emails enviados hasta ahora: 19
# ✔ Email enviado a marypaz@stilhotels.com
# Emails enviados hasta ahora: 20
# ✔ Email enviado a diamond@klaymanaparthotels.com
# Emails enviados hasta ahora: 21
# ✔ Email enviado a olivina@klaymanaparthotels.com
# Emails enviados hasta ahora: 22
# ✔ Email enviado a reservasolivina@klaymanaparthotels.com
# Emails enviados hasta ahora: 23
# ✔ Email enviado a reservas.adeje@myndhotels.com
# Emails enviados hasta ahora: 24
# ✔ Email enviado a info@myndhotels.com
# Emails enviados hasta ahora: 25
# ✔ Email enviado a rgpd@canarianhospitality.com
# Emails enviados hasta ahora: 26
# ✔ Email enviado a ftvreservations@eliteclubresorts.com
# Emails enviados hasta ahora: 27
# ✔ Email enviado a info@eliteclubresorts.com
# Emails enviados hasta ahora: 28
# ✔ Email enviado a hcreservations@eliteclubresorts.com
# Emails enviados hasta ahora: 29
# ✔ Email enviado a francisco.narvaez@onahotels.com
# Emails enviados hasta ahora: 30
# ✔ Email enviado a melania.martin@onahotels.com
# Emails enviados hasta ahora: 31
# ✔ Email enviado a sara.rivera@onahotels.com
# Emails enviados hasta ahora: 32
# ✔ Email enviado a alquilar@belvilla.es
# Emails enviados hasta ahora: 33
# ✔ Email enviado a mailtobook@belvilla.com
# Emails enviados hasta ahora: 34
# ✔ Email enviado a hola@oyorooms.com
# Emails enviados hasta ahora: 35
# ✔ Email enviado a info@adrianhoteles.com
# Emails enviados hasta ahora: 36
# ✔ Email enviado a reservas@adrianhoteles.com
# Emails enviados hasta ahora: 37
# ✔ Email enviado a recepcion.rn@adrianhoteles.com
# Emails enviados hasta ahora: 38
# ✔ Email enviado a info@el-sombrero.com
# Emails enviados hasta ahora: 39
# ✔ Email enviado a support@etistenerife.com
# Emails enviados hasta ahora: 40
# ✔ Email enviado a info@adejeplaza.com
# Emails enviados hasta ahora: 41
# ✔ Email enviado a agents@diviestate.com
# Emails enviados hasta ahora: 42
# ✔ Email enviado a info@apartamentoscarlomar.es
# Emails enviados hasta ahora: 43
# ✔ Email enviado a mailtenerifebliss@gmail.com
# Emails enviados hasta ahora: 44
# ✔ Email enviado a info@mumbaimasalarestaurants.com
# Emails enviados hasta ahora: 45
# ✔ Email enviado a floritasociados@gmail.com
# Emails enviados hasta ahora: 46
# ✔ Email enviado a michelle@buuteeq.com
# Emails enviados hasta ahora: 47
# ✔ Email enviado a erika.ingram@hotmail.com
# Emails enviados hasta ahora: 48
# ✔ Email enviado a nanchuska1@aol.com
# Emails enviados hasta ahora: 49
# ✔ Email enviado a info@neptunoapartments.com
# Emails enviados hasta ahora: 50
# ✔ Email enviado a info@malibutraveltenerife.com
# Emails enviados hasta ahora: 51
# ✔ Email enviado a pdatos@malibutraveltenerife.com
# Emails enviados hasta ahora: 52
# ✔ Email enviado a reservations@diamondgigantes.com
# Emails enviados hasta ahora: 53
# ✔ Email enviado a info@suitevillamaria.com
# Emails enviados hasta ahora: 54
# ✔ Email enviado a saneugenio@saneugenio.es
# Emails enviados hasta ahora: 55
# ✔ Email enviado a reservas@suitevillamaria.es
# Emails enviados hasta ahora: 56
# ✔ Email enviado a villapiedrapura@gmail.com
# Emails enviados hasta ahora: 57
# ✔ Email enviado a sanbenedictoinversiones@gmail.com
# Emails enviados hasta ahora: 58
# ✔ Email enviado a info@sued-teneriffa.de
# Emails enviados hasta ahora: 59
# ✔ Email enviado a mross@jamesvilla.co.uk
# Emails enviados hasta ahora: 60
# ✔ Email enviado a chrisgower@jamesvilla.co.uk
# Emails enviados hasta ahora: 61
# ✔ Email enviado a jon.rodger@wyndhamdn.com
# Emails enviados hasta ahora: 62
# ✔ Email enviado a info@casaamoretenerife.com
# Emails enviados hasta ahora: 63
# ✔ Email enviado a info@luxlivingtenerife.com
# Emails enviados hasta ahora: 64
# ✔ Email enviado a raquel.myers@barcelocrestline.com
# Emails enviados hasta ahora: 65
# ✔ Email enviado a nancy.gulli@barcelocrestline.com
# Emails enviados hasta ahora: 66
# ✔ Email enviado a crystin.andeel@barcelocrestline.com
# Emails enviados hasta ahora: 67
# ✔ Email enviado a accounting@tierrazulsuitesart.com
# Emails enviados hasta ahora: 68
# ✔ Email enviado a post@teneriffa-haus.de
# Emails enviados hasta ahora: 69
# ✔ Email enviado a info@eliteluxuryvacations.com
# Emails enviados hasta ahora: 70
# ✔ Email enviado a sainversionescanarias@gmail.com
# Emails enviados hasta ahora: 71
# ✔ Email enviado a cafe@lacasitacafe.es
# Emails enviados hasta ahora: 72
# ✔ Email enviado a info@villadhanvantari.com
# Emails enviados hasta ahora: 73
# (221,
#  b'2.0.0 closing connection ffacd0b85a97d-43796a6a6desm3126303f8f.10 - gsmtp')
