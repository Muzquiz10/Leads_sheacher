# %%
import os
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import time
import os
from dotenv import load_dotenv

# %%
## Función

def apendizador_leads(ruta,sector):
    dfs = []

    for entry in os.scandir(ruta):
        if entry.is_file() and sector in entry.name:
            df = pd.read_csv(entry.path)

            # -------------------------
            # LIMPIEZA DE DATOS (ejemplo)
            # -------------------------
            df = df.dropna(subset=['Email'])          # elimina registros sin email
        

            # Guarda el dataframe limpio
            dfs.append(df)

    # Unir todos los dataframes en uno solo
    df_final = pd.concat(dfs, ignore_index=True)
    df_final.to_excel(ruta + f"/leads_{sector}_completo.xlsx", index=False)

    return df_final

# %%
df = apendizador_leads(r"C:\Users\ejgar\OneDrive\Documentos\GitHub\Leads_sheacher\data\7.Spa","Spa")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     111 non-null    object
#  1   Direccion  111 non-null    object
#  2   Telefono   110 non-null    object
#  3   Web        111 non-null    object
#  4   Email      111 non-null    object
#  5   Sector     111 non-null    object
#  6   Ubicacion  111 non-null    object
# dtypes: object(7)
# memory usage: 6.2+ KB

# %%
df.head()
# Out:
#                                               Nombre  \
# 0  JG fitness Alcobendas | Entrenador personal & ...
# 1  Nkon Training | Centro de Entrenamiento Person...
# 2  SANO Alcobendas - Entrenamiento Personal y Gru...
# 3  ENTRENADOR PERSONAL (PAUL CORDONES) Moraleja -...
# 4                    Jorge Morillas Personal Trainer
#
#                                            Direccion          Telefono  \
# 0   P.º de la Chopera, 182, 28100 Alcobendas, Madrid  +34 604 97 78 56
# 1  Av. de la Industria, 34, Primera Planta. Local...               NaN
# 2  Av. de Camilo José Cela, 34, 28108 Alcobendas,...  +34 614 14 27 03
# 3       Pl. de la Moraleja, 28109 Alcobendas, Madrid  +34 653 04 36 43
# 4    C. de la Libertad, 49, 28100 Alcobendas, Madrid  +34 689 48 86 33
#
#                                                  Web  \
# 0           https://jgfitness.es/centros/alcobendas/
# 1                       https://www.nkontraining.es/
# 2  https://www.sanocenter.es/empresas/sano-alcobe...
# 3                           http://paulcordones.com/
# 4                         https://jorgemorillas.com/
#
#                                 Email               Sector   Ubicacion
# 0        DSC03954_@sharonlopez-1.webp  Entrenador Personal  Alcobendas
# 1                info@nkontraining.es  Entrenador Personal  Alcobendas
# 2  sanomadridalcobendas@sanocenter.es  Entrenador Personal  Alcobendas
# 3               info@paulcordones.com  Entrenador Personal  Alcobendas
# 4     jorgemorillas.trainer@gmail.com  Entrenador Personal  Alcobendas

# %% [markdown]
# ## Envío de mail

# %%
df = pd.read_excel(r"C:\Users\ejgar\OneDrive\Documentos\GitHub\Leads_sheacher\data\2.Estetica\leads_estetica_completo.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     80 non-null     object
#  1   Direccion  80 non-null     object
#  2   Telefono   80 non-null     object
#  3   Web        80 non-null     object
#  4   Email      80 non-null     object
#  5   Sector     80 non-null     object
#  6   Ubicacion  80 non-null     object
# dtypes: object(7)
# memory usage: 4.5+ KB

# %%
# Particionado del Dataframe
df_particionado = df.iloc[40:] ## Para particionar el df en varias partes
df_particionado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 40 to 110
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     71 non-null     object
#  1   Direccion  71 non-null     object
#  2   Telefono   71 non-null     object
#  3   Web        71 non-null     object
#  4   Email      71 non-null     object
#  5   Sector     71 non-null     object
#  6   Ubicacion  71 non-null     object
# dtypes: object(7)
# memory usage: 4.0+ KB

# %%
df_particionado.head()
# Out:
#                                                Nombre  \
# 40                       Wellness Boutique Experience
# 41                              Hotel Plaza Las Matas
# 42                           Gravity Zero ı Urban Spa
# 43                                     Armoni Belleza
# 44  Madrid Aquagrup - Aquavia Spa y Jacuzzi para E...
#
#                                             Direccion          Telefono  \
# 40           C. de Campoamor, 5, Centro, 28004 Madrid  +34 917 37 35 95
# 41  C. Martín Iriarte, 2F, 28290 Las Rozas de Madr...  +34 657 81 95 20
# 42  Av. Isabel de Farnesio, 34, 28660 Boadilla del...  +34 660 08 01 52
# 43  C. Camilo José Cela, 4, C, 28232 Las Rozas de ...  +34 623 20 41 93
# 44  C. Módena, 3, Európolis, 28232 Las Rozas de Ma...  +34 919 34 73 50
#
#                                    Web  \
# 40     https://www.wellnessmadrid.com/
# 41  http://www.hotelplazalasmatas.com/
# 42       http://www.gzerourbanspa.com/
# 43           https://armonibelleza.es/
# 44                https://aquagrup.es/
#
#                                       Email Sector  Ubicacion
# 40                  info@wellnessmadrid.com    Spa  Las Rozas
# 41          reservas@hotelplazalasmatas.com    Spa  Las Rozas
# 42  cropped-favicon-gzero@2x-32x32.png.webp    Spa  Las Rozas
# 43                  armonibelleza@gmail.com    Spa  Las Rozas
# 44                         info@aquagrup.es    Spa  Las Rozas

# %%
# Credenciales Gmail
load_dotenv()

EMAIL_REMITENTE = os.getenv("EMAIL_REMITENTE")
PASSWORD_APP = os.getenv("PASSWORD_APP")
SMTP_SERVER = os.getenv("SMTP_SERVER")
SMTP_PORT = int(os.getenv("SMTP_PORT"))

EMAIL_REMITENTE = EMAIL_REMITENTE
PASSWORD_APP = PASSWORD_APP

# servidor SMTP de Gmail
SMTP_SERVER = SMTP_SERVER
SMTP_PORT = SMTP_PORT

# conexión
server = smtplib.SMTP(SMTP_SERVER, SMTP_PORT)
server.starttls()
server.login(EMAIL_REMITENTE, PASSWORD_APP)

#Contador de mails enviaados
contador = 0

for _, row in df.iterrows():
    ### Pruebas ###
    # nombre = "Enrique" #Para pruebas
    # destinatario = "muzquiz.10@gmail.com"  #Para pruebas
    ## Fin Pruebas ##

    destinatario = row['Email']
    nombre = row['Nombre']
    
    mensaje = MIMEMultipart()
    mensaje['From'] = EMAIL_REMITENTE
    mensaje['To'] = destinatario
    mensaje['Subject'] = "Datos claros y una presencia online profesional para tu negocio"

    cuerpo = f"""
Hola {nombre},

Soy Enrique García, consultor freelance y fundador de EGM Analytics.

Ayudo a pequeños negocios y profesionales en dos áreas clave:

Business Intelligence y análisis de datos: organización y modelado de datos, automatización de informes, análisis para la toma de decisiones y mejora de procesos basados en datos.

Desarrollo web profesional: creación de páginas web claras y bien estructuradas que ayuden a tener presencia online, transmitir credibilidad y mostrar el negocio de forma profesional.

En muchos casos me encuentro con empresas que tienen datos dispersos o infrautilizados y, al mismo tiempo, una presencia digital que no refleja realmente lo que hacen o el valor que aportan.

Mi enfoque es práctico y cercano: soluciones sencillas, bien pensadas y adaptadas a cada negocio, sin complicaciones innecesarias.

Si te parece, podemos agendar una llamada breve (15–20 minutos, sin compromiso) para comentar tu situación y ver si puedo ayudarte en alguno de estos ámbitos.

También me puedes conocer a través de mi web: https://egmanalytics.com

Un saludo,


Enrique García
Consultor en Data, BI y Desarrollo Web
EGM Analytics
https://egmanalytics.com
"""
    mensaje.attach(MIMEText(cuerpo, 'plain'))

    try:
        server.send_message(mensaje)
        print(f"✔ Email enviado a {destinatario}")
        contador += 1
        print(f"Emails enviados hasta ahora: {contador}")
        time.sleep(15)
    except Exception as e:
        print(f"❌ Error enviando a {destinatario}: {e}")
        time.sleep(15)

server.quit()
# Out:
# ✔ Email enviado a esteticamartaaguayo@gmail.com
# Emails enviados hasta ahora: 1
# ✔ Email enviado a info@soymedicinaestetica.com
# Emails enviados hasta ahora: 2
# ✔ Email enviado a info@venusmed.clinic
# Emails enviados hasta ahora: 3
# ✔ Email enviado a pv@eternalbeautyclinic.com
# Emails enviados hasta ahora: 4
# ✔ Email enviado a n@clinicatrevi.com
# Emails enviados hasta ahora: 5
# ✔ Email enviado a info@clinicaesteticamadridcentro.com
# Emails enviados hasta ahora: 6
# ✔ Email enviado a hola@amaranestetica.es
# Emails enviados hasta ahora: 7
# ✔ Email enviado a info@esteticadelamirada.es
# Emails enviados hasta ahora: 8
# ✔ Email enviado a clinica@fercasy.com
# Emails enviados hasta ahora: 9
# ✔ Email enviado a durandomedicinaestetica@gmail.com
# Emails enviados hasta ahora: 10
# ✔ Email enviado a %20femsiebelleza@gmail.com
# Emails enviados hasta ahora: 11
# ✔ Email enviado a estetica.himandher@gmail.com
# Emails enviados hasta ahora: 12
# ✔ Email enviado a spalookgerencia@gmail.com
# Emails enviados hasta ahora: 13
# ✔ Email enviado a info@drelenaberezo.com
# Emails enviados hasta ahora: 14
# ✔ Email enviado a mq@montserratquiros.es
# Emails enviados hasta ahora: 15
# ✔ Email enviado a info@brentonclinic.com
# Emails enviados hasta ahora: 16
# ✔ Email enviado a tbcchile@thebeautyconcept.com
# Emails enviados hasta ahora: 17
# ✔ Email enviado a edytabeauty@gmail.com
# Emails enviados hasta ahora: 18
# ❌ Error enviando a info@thesecretlab.es: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 5b1f17b1804b1-47ee0b488d4sm6269705e9.0 - gsmtp')
# ❌ Error enviando a citas@ecoteliernatural.es: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 5b1f17b1804b1-47ee0b488d4sm6269705e9.0 - gsmtp')
# ❌ Error enviando a gp@eternalbeautyclinic.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 5b1f17b1804b1-47ee0b488d4sm6269705e9.0 - gsmtp')
# ---------------------------------------------------------------------------
# SMTPDataError                             Traceback (most recent call last)
# Cell In[17], line 68
#      67 try:
# ---> 68     server.send_message(mensaje)
#      69     print(f"✔ Email enviado a {destinatario}")
#
# File c:\Users\ejgar\AppData\Local\Programs\Python\Python313\Lib\smtplib.py:975, in SMTP.send_message(self, msg, from_addr, to_addrs, mail_options, rcpt_options)
#     974     flatmsg = bytesmsg.getvalue()
# --> 975 return self.sendmail(from_addr, to_addrs, flatmsg, mail_options,
#     976                      rcpt_options)
#
# File c:\Users\ejgar\AppData\Local\Programs\Python\Python313\Lib\smtplib.py:891, in SMTP.sendmail(self, from_addr, to_addrs, msg, mail_options, rcpt_options)
#     890     raise SMTPRecipientsRefused(senderrs)
# --> 891 (code, resp) = self.data(msg)
#     892 if code != 250:
#
# File c:\Users\ejgar\AppData\Local\Programs\Python\Python313\Lib\smtplib.py:571, in SMTP.data(self, msg)
#     570 if code != 354:
# --> 571     raise SMTPDataError(code, repl)
#     572 else:
#
# SMTPDataError: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 5b1f17b1804b1-47ee0b488d4sm6269705e9.0 - gsmtp')
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 75
#      73     except Exception as e:
#      74         print(f"❌ Error enviando a {destinatario}: {e}")
# ---> 75         time.sleep(15)
#      77 server.quit()
#
# KeyboardInterrupt:
